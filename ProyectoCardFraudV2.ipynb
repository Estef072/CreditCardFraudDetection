# %%
import pandas as pd

# %%
df=pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.hist(bins=30, figsize=(30, 30))
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
# ...

# %%
pd.value_counts(df['Class']).plot.bar()
# Out:
# C:\Users\Estefanía E\AppData\Local\Temp\ipykernel_11104\3245061895.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df['Class']).plot.bar()
# <Axes: xlabel='Class'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo para las gráficas
sns.set(style="whitegrid")

# Distribución de la Variable 'Amount' (Enfoque en Transacciones Menores)
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Amount'] <= 200]['Amount'], bins=40, kde=True)
plt.title('Distribución de la Cantidad de Transacciones (Hasta 200)')
plt.xlabel('Amount')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
# Análisis de Variables 'V1' a 'V28'
plt.figure(figsize=(12, 10))
df.iloc[:, 1:29].boxplot()
plt.title('Boxplot de las Variables V1 a V28')
plt.xlabel('Variables')
plt.ylabel('Valores')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Relación entre 'Amount' y 'Class'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Class', y='Amount', data=df)
plt.title('Relación entre Cantidad de Transacción y Clase')
plt.xlabel('Class (0: No Fraude, 1: Fraude)')
plt.ylabel('Amount')
plt.ylim([0, 400])  # Limitar el eje y para una mejor visualización
plt.grid(True)
plt.show()

# %%
# Relación entre 'Time' y 'Class'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Class', y='Time', data=df)
plt.title('Relación entre Tiempo de Transacción y Clase')
plt.xlabel('Class (0: No Fraude, 1: Fraude)')
plt.ylabel('Time')
plt.grid(True)
plt.show()

# %%
# Generando la matriz de correlación
corr_matrix = df.corr()

# Visualización de la matriz de correlación
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %%
len(df.columns)
# Out:
# 31

# %%
X=df.iloc[:,1:30]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
y_train.value_counts()
# Out:
# Class
# 0    199008
# 1       356
# Name: count, dtype: int64

# %%
##Step1
import tensorflow
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

n_inputs=29

# define model
model = Sequential()
# define first hidden layer and visible layer
model.add(Dense(50, input_dim=n_inputs, activation='relu', kernel_initializer='he_uniform'))
# define output layer
model.add(Dense(1, activation='sigmoid'))
# define loss and optimizer
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train,y_train,epochs=10)

from sklearn.metrics import roc_auc_score
y_pred1=model.predict(X_test)

print(roc_auc_score(y_test,y_pred1))
# Out:
# WARNING:tensorflow:From C:\Users\Estefanía E\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Estefanía E\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Estefanía E\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Estefanía E\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# ...

# %%
import tensorflow
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score, f1_score, precision_score, accuracy_score, roc_curve, classification_report
import numpy as np

# Realizar predicciones
y_pred1 = model.predict(X_test)

y_pred_binary = (y_pred1 > 0.5).astype(int).flatten()

# Calculate F1-score, precision, and accuracy
f1 = f1_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
accuracy = accuracy_score(y_test, y_pred_binary)

# Calculate ROC AUC Score
# Nota: roc_auc_score necesita las puntuaciones de probabilidad de las predicciones, no las predicciones binarias
roc_auc = roc_auc_score(y_test, y_pred1)

# Generate a classification report
report = classification_report(y_test, y_pred_binary)

# Print the evaluation metrics
print("F1-Score:", f1)
print("Precision:", precision)
print("Accuracy:", accuracy)
print("ROC AUC Score:", roc_auc)
print("\nClassification Report:\n", report)
# Out:
# 2671/2671 [==============================] - 6s 2ms/step
# F1-Score: 0.8288973384030418
# Precision: 0.8582677165354331
# Accuracy: 0.9994733330992591
# ROC AUC Score: 0.9662121289956896
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.86      0.80      0.83       136
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.90      0.91     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Calculando la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred_binary)

# Graficando la matriz de confusión
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Calculando la curva ROC
fpr, tpr, _ = roc_curve(y_test, y_pred1)

# Graficando la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, InputLayer, BatchNormalization
from sklearn.metrics import classification_report, precision_score, f1_score, roc_auc_score
from sklearn.utils import class_weight
import numpy as np
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import roc_curve

file_path = 'creditcard.csv'
credit_card_data = pd.read_csv(file_path)
X = credit_card_data.drop('Class', axis=1)
y = credit_card_data['Class']

# Normalización de los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# División en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Calcular pesos de clase
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(enumerate(weights))

# Tu modelo existente modificado
model = Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compilación y entrenamiento igual que antes
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0001), metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_test, y_test))

# Realizar predicciones
y_pred_proba = model.predict(X_test).ravel()

# Calcular curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Encontrar el mejor umbral
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

# Aplicar el umbral óptimo para clasificación binaria
y_pred_optimal = (y_pred_proba >= optimal_threshold).astype(int)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/10
# 3561/3561 [==============================] - 22s 5ms/step - loss: 0.1801 - accuracy: 0.9829 - val_loss: 0.0342 - val_accuracy: 0.9993
# Epoch 2/10
# 3561/3561 [==============================] - 17s 5ms/step - loss: 0.0213 - accuracy: 0.9989 - val_loss: 0.0183 - val_accuracy: 0.9993
# Epoch 3/10
# 3561/3561 [==============================] - 18s 5ms/step - loss: 0.0159 - accuracy: 0.9989 - val_loss: 0.0143 - val_accuracy: 0.9993
# Epoch 4/10
# 3561/3561 [==============================] - 17s 5ms/step - loss: 0.0132 - accuracy: 0.9989 - val_loss: 0.0114 - val_accuracy: 0.9992
# Epoch 5/10
# 3561/3561 [==============================] - 16s 4ms/step - loss: 0.0119 - accuracy: 0.9990 - val_loss: 0.0192 - val_accuracy: 0.9978
# Epoch 6/10
# ...

# %%
import tensorflow
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score, f1_score, precision_score, accuracy_score, roc_curve, classification_report
import numpy as np

# Realizar predicciones
y_pred1 = model.predict(X_test)

y_pred_binary = (y_pred1 > 0.5).astype(int).flatten()

# Calculate F1-score, precision, and accuracy
f1 = f1_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
accuracy = accuracy_score(y_test, y_pred_binary)

# Calculate ROC AUC Score
# Nota: roc_auc_score necesita las puntuaciones de probabilidad de las predicciones, no las predicciones binarias
roc_auc = roc_auc_score(y_test, y_pred1)

# Generate a classification report
report = classification_report(y_test, y_pred_binary)

# Print the evaluation metrics
print("F1-Score:", f1)
print("Precision:", precision)
print("Accuracy:", accuracy)
print("ROC AUC Score:", roc_auc)
print("\nClassification Report:\n", report)
# Out:
# 1781/1781 [==============================] - 3s 2ms/step
# F1-Score: 0.6909090909090908
# Precision: 0.8507462686567164
# Accuracy: 0.9991046662687406
# ROC AUC Score: 0.9229209973240844
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.85      0.58      0.69        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.79      0.85     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Calculando la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred_binary)

# Graficando la matriz de confusión
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Calculando la curva ROC
fpr, tpr, _ = roc_curve(y_test, y_pred1)

# Graficando la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()
