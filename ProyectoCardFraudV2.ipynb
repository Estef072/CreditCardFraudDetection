# %%
import pandas as pd

# %%
df=pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.hist(bins=30, figsize=(30, 30))
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
#         <Axes: title={'center': 'V26'}>, <Axes: title={'center': 'V27'}>,
#         <Axes: title={'center': 'V28'}>,
#         <Axes: title={'center': 'Amount'}>],
#        [<Axes: title={'center': 'Class'}>, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
pd.value_counts(df['Class']).plot.bar()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo para las gráficas
sns.set(style="whitegrid")

# Distribución de la Variable 'Amount' (Enfoque en Transacciones Menores)
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Amount'] <= 200]['Amount'], bins=40, kde=True)
plt.title('Distribución de la Cantidad de Transacciones (Hasta 200)')
plt.xlabel('Amount')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
# Análisis de Variables 'V1' a 'V28'
plt.figure(figsize=(12, 10))
df.iloc[:, 1:29].boxplot()
plt.title('Boxplot de las Variables V1 a V28')
plt.xlabel('Variables')
plt.ylabel('Valores')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Relación entre 'Amount' y 'Class'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Class', y='Amount', data=df)
plt.title('Relación entre Cantidad de Transacción y Clase')
plt.xlabel('Class (0: No Fraude, 1: Fraude)')
plt.ylabel('Amount')
plt.ylim([0, 400])  # Limitar el eje y para una mejor visualización
plt.grid(True)
plt.show()

# %%
# Relación entre 'Time' y 'Class'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Class', y='Time', data=df)
plt.title('Relación entre Tiempo de Transacción y Clase')
plt.xlabel('Class (0: No Fraude, 1: Fraude)')
plt.ylabel('Time')
plt.grid(True)
plt.show()

# %%
# Generando la matriz de correlación
corr_matrix = df.corr()

# Visualización de la matriz de correlación
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %%
len(df.columns)
# Out:
# 31

# %%
X=df.iloc[:,1:30]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
y_train.value_counts()
# Out:
# 0    199008
# 1       356
# Name: Class, dtype: int64

# %%
##Step1
import tensorflow
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

n_inputs=29

# define model
model = Sequential()
# define first hidden layer and visible layer
model.add(Dense(50, input_dim=n_inputs, activation='relu', kernel_initializer='he_uniform'))
# define output layer
model.add(Dense(1, activation='sigmoid'))
# define loss and optimizer
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train,y_train,epochs=10)

from sklearn.metrics import roc_auc_score
y_pred1=model.predict(X_test)

print(roc_auc_score(y_test,y_pred1))
# Out:
# Epoch 1/10
# 6231/6231 [==============================] - 3s 529us/step - loss: 0.0241 - accuracy: 0.9983
# Epoch 2/10
# 6231/6231 [==============================] - 3s 521us/step - loss: 0.0130 - accuracy: 0.9991
# Epoch 3/10
# 6231/6231 [==============================] - 3s 541us/step - loss: 0.0103 - accuracy: 0.9992
# Epoch 4/10
# 6231/6231 [==============================] - 3s 520us/step - loss: 0.0127 - accuracy: 0.9992
# Epoch 5/10
# 6231/6231 [==============================] - 3s 524us/step - loss: 0.0113 - accuracy: 0.9992
# Epoch 6/10
# 6231/6231 [==============================] - 3s 529us/step - loss: 0.0075 - accuracy: 0.9993
# Epoch 7/10
# 6231/6231 [==============================] - 3s 561us/step - loss: 0.0069 - accuracy: 0.9993
# Epoch 8/10
# 6231/6231 [==============================] - 3s 526us/step - loss: 0.0061 - accuracy: 0.9994
# Epoch 9/10
# 6231/6231 [==============================] - 3s 508us/step - loss: 0.0082 - accuracy: 0.9993
# Epoch 10/10
# 6231/6231 [==============================] - 3s 510us/step - loss: 0.0068 - accuracy: 0.9993
# 2671/2671 [==============================] - 1s 339us/step
# 0.9335938227260849

# %%
import tensorflow
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score, f1_score, precision_score, accuracy_score, roc_curve, classification_report
import numpy as np

# Realizar predicciones
y_pred1 = model.predict(X_test)

y_pred_binary = (y_pred1 > 0.5).astype(int).flatten()

# Calculate F1-score, precision, and accuracy
f1 = f1_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
accuracy = accuracy_score(y_test, y_pred_binary)

# Calculate ROC AUC Score
# Nota: roc_auc_score necesita las puntuaciones de probabilidad de las predicciones, no las predicciones binarias
roc_auc = roc_auc_score(y_test, y_pred1)

# Generate a classification report
report = classification_report(y_test, y_pred_binary)

# Print the evaluation metrics
print("F1-Score:", f1)
print("Precision:", precision)
print("Accuracy:", accuracy)
print("ROC AUC Score:", roc_auc)
print("\nClassification Report:\n", report)
# Out:
# 2671/2671 [==============================] - 1s 341us/step
# F1-Score: 0.7933884297520662
# Precision: 0.9056603773584906
# Accuracy: 0.9994148145547324
# ROC AUC Score: 0.9335938227260849
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.91      0.71      0.79       136
#
#     accuracy                           1.00     85443
#    macro avg       0.95      0.85      0.90     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
##Modelo 2 Usando pesos 
weights_assigned={0:1,1:550}
# define model
model = Sequential()
# define first hidden layer and visible layer
model.add(Dense(50, input_dim=n_inputs, activation='relu', kernel_initializer='he_uniform'))
# define output layer
model.add(Dense(1, activation='sigmoid'))
# define loss and optimizer
model.compile(loss='binary_crossentropy', optimizer='adam')
model.fit(X_train,y_train,class_weight=weights_assigned,epochs=10)
# Out:
# Epoch 1/10
# 6231/6231 [==============================] - 4s 583us/step - loss: 5.7264
# Epoch 2/10
# 6231/6231 [==============================] - 4s 566us/step - loss: 2.6651
# Epoch 3/10
# 6231/6231 [==============================] - 4s 595us/step - loss: 2.4897
# Epoch 4/10
# 6231/6231 [==============================] - 3s 556us/step - loss: 2.1180
# Epoch 5/10
# 6231/6231 [==============================] - 3s 555us/step - loss: 2.5188
# Epoch 6/10
# 6231/6231 [==============================] - 3s 554us/step - loss: 2.5420
# Epoch 7/10
# 6231/6231 [==============================] - 3s 548us/step - loss: 2.8935
# Epoch 8/10
# 6231/6231 [==============================] - 3s 553us/step - loss: 2.5213
# Epoch 9/10
# 6231/6231 [==============================] - 4s 567us/step - loss: 2.6617
# Epoch 10/10
# 6231/6231 [==============================] - 4s 575us/step - loss: 2.1426

# %%
import tensorflow
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score, f1_score, precision_score, accuracy_score, roc_curve, classification_report
import numpy as np

# Realizar predicciones
y_pred1 = model.predict(X_test)

y_pred_binary = (y_pred1 > 0.5).astype(int).flatten()

# Calculate F1-score, precision, and accuracy
f1 = f1_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
accuracy = accuracy_score(y_test, y_pred_binary)

# Calculate ROC AUC Score
# Nota: roc_auc_score necesita las puntuaciones de probabilidad de las predicciones, no las predicciones binarias
roc_auc = roc_auc_score(y_test, y_pred1)

# Generate a classification report
report = classification_report(y_test, y_pred_binary)

# Print the evaluation metrics
print("F1-Score:", f1)
print("Precision:", precision)
print("Accuracy:", accuracy)
print("ROC AUC Score:", roc_auc)
print("\nClassification Report:\n", report)
# Out:
# 2671/2671 [==============================] - 1s 350us/step
# F1-Score: 0.06246949731576379
# Precision: 0.03230691569914185
# Accuracy: 0.9550343503856372
# ROC AUC Score: 0.9810341145027062
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     85307
#            1       0.03      0.94      0.06       136
#
#     accuracy                           0.96     85443
#    macro avg       0.52      0.95      0.52     85443
# weighted avg       1.00      0.96      0.98     85443

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, InputLayer, BatchNormalization
from sklearn.metrics import classification_report, precision_score, f1_score, roc_auc_score
from sklearn.utils import class_weight
import numpy as np
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import roc_curve

# Carga de datos (asegúrate de tener 'credit_card_data' definido)
# credit_card_data = ...
file_path = 'creditcard.csv'
credit_card_data = pd.read_csv(file_path)
X = credit_card_data.drop('Class', axis=1)
y = credit_card_data['Class']

# Normalización de los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# División en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Calcular pesos de clase
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(enumerate(weights))

# Tu modelo existente modificado
model = Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compilación y entrenamiento igual que antes
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0001), metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_test, y_test))

# Realizar predicciones
y_pred_proba = model.predict(X_test).ravel()

# Calcular curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Encontrar el mejor umbral
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

# Aplicar el umbral óptimo para clasificación binaria
y_pred_optimal = (y_pred_proba >= optimal_threshold).astype(int)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/10
# 3561/3561 [==============================] - 4s 947us/step - loss: 0.1846 - accuracy: 0.9829 - val_loss: 0.0391 - val_accuracy: 0.9993
# Epoch 2/10
# 3561/3561 [==============================] - 3s 920us/step - loss: 0.0233 - accuracy: 0.9988 - val_loss: 0.0216 - val_accuracy: 0.9994
# Epoch 3/10
# 3561/3561 [==============================] - 3s 916us/step - loss: 0.0150 - accuracy: 0.9989 - val_loss: 0.0151 - val_accuracy: 0.9993
# Epoch 4/10
# 3561/3561 [==============================] - 3s 911us/step - loss: 0.0129 - accuracy: 0.9988 - val_loss: 0.0186 - val_accuracy: 0.9991
# Epoch 5/10
# 3561/3561 [==============================] - 3s 911us/step - loss: 0.0117 - accuracy: 0.9990 - val_loss: 0.0135 - val_accuracy: 0.9993
# Epoch 6/10
# 3561/3561 [==============================] - 3s 907us/step - loss: 0.0110 - accuracy: 0.9989 - val_loss: 0.0102 - val_accuracy: 0.9993
# Epoch 7/10
# 3561/3561 [==============================] - 3s 904us/step - loss: 0.0102 - accuracy: 0.9989 - val_loss: 0.0112 - val_accuracy: 0.9993
# Epoch 8/10
# 3561/3561 [==============================] - 3s 905us/step - loss: 0.0098 - accuracy: 0.9990 - val_loss: 0.0116 - val_accuracy: 0.9993
# Epoch 9/10
# 3561/3561 [==============================] - 3s 910us/step - loss: 0.0098 - accuracy: 0.9989 - val_loss: 0.0098 - val_accuracy: 0.9994
# Epoch 10/10
# 3561/3561 [==============================] - 3s 907us/step - loss: 0.0092 - accuracy: 0.9990 - val_loss: 0.0080 - val_accuracy: 0.9994
# 1781/1781 [==============================] - 1s 408us/step

# %%
import tensorflow
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score, f1_score, precision_score, accuracy_score, roc_curve, classification_report
import numpy as np

# Realizar predicciones
y_pred1 = model.predict(X_test)

y_pred_binary = (y_pred1 > 0.5).astype(int).flatten()

# Calculate F1-score, precision, and accuracy
f1 = f1_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
accuracy = accuracy_score(y_test, y_pred_binary)

# Calculate ROC AUC Score
# Nota: roc_auc_score necesita las puntuaciones de probabilidad de las predicciones, no las predicciones binarias
roc_auc = roc_auc_score(y_test, y_pred1)

# Generate a classification report
report = classification_report(y_test, y_pred_binary)

# Print the evaluation metrics
print("F1-Score:", f1)
print("Precision:", precision)
print("Accuracy:", accuracy)
print("ROC AUC Score:", roc_auc)
print("\nClassification Report:\n", report)
# Out:
# 1781/1781 [==============================] - 1s 459us/step
# F1-Score: 0.8021978021978022
# Precision: 0.8690476190476191
# Accuracy: 0.9993679997191109
# ROC AUC Score: 0.9503769466424725
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.87      0.74      0.80        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.87      0.90     56962
# weighted avg       1.00      1.00      1.00     56962
